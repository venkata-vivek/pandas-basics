# %%
import pandas as pd

pd.set_option('display.max_columns',120)
pd.set_option('display.max_rows',100)

df = pd.read_csv('./data/survey_results_public.csv',index_col='ResponseId')
schema_df = pd.read_csv('./data/survey_results_schema.csv',index_col='qname')

# %%
filt = df['Country'] == 'India'

India_df = df.loc[filt]

# %%
India_df.to_csv('./data/raw.csv')

# %%
# %pip install xlrd openpyxl xlrd
# Out:
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# ...
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
India_df.to_csv('./data/modified.csv',sep='\t')

# %%
India_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx',index_col='ResponseId')

# %%
test.head(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
# 106                            I am a developer by profession
# 127                            I am a developer by profession
# 141         I am not primarily a developer, but I write co...
# 143         I am not primarily a developer, but I write co...
# 165                            I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
# 106         25-34 years old
# 127         25-34 years old
# ...

# %%
# Orient the record in lines 
India_df.to_json('data/modified.json',orient='records',lines=True)

# %%
test = pd.read_json('data/modified.json',orient='record',lines=True)

# %%
#READ AND WRIT TO AN SQL DATABASE

from sqlalchemy import create_engine
import psycopg2

engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
# Write to sql 
India_df.to_sql('sample_table',engine, if_exists='replace')

# %%
# Read from sql 
sql_df = pd.read_sql('sample_table',engine, index_col='Respondent')

sql_df.head(10)

# %%
sql_df = pd.read_sql_query('SELECT * FROM  sample_table',engine, index_col='Respondent')

# %%
sql_df.head()

# %%
# Load from url directly 
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df.head(10)
# Out:
#                                            title  \
# 0                                My Updated Post
# 1                                  A Second Post
# 2                   Top 5 Programming Lanaguages
# 3                   Sublime Text Tips and Tricks
# 4                               Best Python IDEs
# 5             Flask vs Django - Which Is Better?
# 6      You Won't Believe These Clickbait Titles!
# 7      These Beers Will Improve Your Programming
# 8                       List of PyCon 2018 Talks
# 9  How Dogs in the Workplace Boosts Productivity
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1
# ...
